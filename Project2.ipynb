# %% [markdown]
# # Team info:
#
# Project Title: Analysis of University Rankings in VA and Student Outcomes
#
# Team name: Algorithm Avengers
#
# Team member names and PIDs:
# - Esther Kim - estherkdy
# - Kaitlyn Green - kaitlyngreen
# - Ben Clements - benc04
# - Hieu Ngo - hieu
# - Jackson Rowley - jacksonrowley04

# %% [markdown]
# # Project introduction:
# ### Initial description of the project topic
#
# Investigate relation between University Rankings and employment rates, income, salary growth, and average debt.
#
#
# ### Potential research questions you plan to address
#
# What factors most significantly influence university rankings among Virginia universities?
#
# Is there a correlation between university rankings and graduate employment rates in Virginia?
#
# Is there a correlation between university rankings and starting salary?
#
# Is there a correlation between university rankings and salary growth in the first few years?
#
# How does school ranking correlate with job placement and salary trends in different industries?
#
# What is the impact of new degrees on employment rates?
#
# Is there a correlation between tuition and university ranking? (New research question)
#
# ### Description of potential source data that would be relevant (including links or references if possible).
#
# Best Colleges in Virginia and Categorial Rankings: https://www.usnews.com/best-colleges/va
#
# List of Colleges & Universities in VA with school populations:
# https://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Virginia
#
# Offers salary data based on employment reports, filtering by degree, and more possible:
# https://www.glassdoor.com/index.htm.
#
# US Dept of Education, has tuition, mean salary, and graduation rate of universities:
# https://collegescorecard.ed.gov/school/?234076-University-of-Virginia-Main-Campus

# %%
# imports
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# This code cell is reading an updated .csv file pulled from https://www.usnews.com/best-colleges/va?_sort=rank&_sortDirection=asc, which ranks universities and college in VA. The normal .csv, had unavailable data for in-state pricing for mostly private schools, as they do not techically have in-state rates, as well as two schools with no ranking. The 'not avaible' data for the private schools was copied over from out-of-state tuition to in-state for the respective schools, and the schools with no ranking were removed. The only public school with no pricing data pulled from US News was VMI, and the cells for tuiton were filled with tuition rates from their website for the 2024-2025 school year. This was also done for private schools with no data available for out-of-state and in-state tuition from US News. A VA Rank column was also added to the file as well.
# - Esther Kim, retrieved, original csv file
# - Kaitlyn Green, updated US_news_ranking_.csv, wrote this markdown cell

# %%
# df = pd.read_csv('US_news_ranking.csv')
df = pd.read_csv('US_news_ranking_UPDATED.csv') 

df
# Out:
#                                 Name              Location National Rank  \
# 0             University of Virginia    Charlottesville VA            24
# 1                      Virginia Tech         Blacksburg VA            51
# 2                     William & Mary       Williamsburg VA            54
# 3            George Mason University            Fairfax VA           109
# 4   Virginia Commonwealth University           Richmond VA           136
# 5           James Madison University       Harrisonburg VA           148
# 6                 Hampton University            Hampton VA           273
# 7               Marymount University          Arlington VA           288
# 8            Old Dominion University            Norfolk VA           296
# 9                 Radford University            Radford VA           315
# 10             Shenandoah University         Winchester VA           315
# 11           University of Lynchburg          Lynchburg VA           329
# 12           Mary Baldwin University           Staunton VA           377
# 13                 Regent University     Virginia Beach VA           377
# 14     Washington and Lee University          Lexington VA            19
# 15            University of Richmond  Univ. of Richmond VA            22
# 16       Virginia Military Institute          Lexington VA            59
# 17            Hampden-Sydney College     Hampden-Sydney VA           103
# 18            Randolph-Macon College            Ashland VA           103
# 19                   Roanoke College              Salem VA           122
# 20     University of Mary Washington     Fredericksburg VA           132
# 21                Hollins University            Roanoke VA           136
# 22             Patrick Henry College       Purcellville VA           136
# 23                  Randolph College          Lynchburg VA           162
# 24               Bridgewater College        Bridgewater VA           165
# 25               Sweet Briar College        Sweet Briar VA           173
# 26      University of Virginia--Wise               Wise VA           173
# 27      Virginia Wesleyan University     Virginia Beach VA           175
# 28      Southern Virginia University        Buena Vista VA           182
# 29    Christopher Newport University       Newport News VA             6
# 30               Longwood University          Farmville VA            15
# 31          Emory & Henry University              Emory VA            26
# 32      Eastern Mennonite University       Harrisonburg VA            48
# 33                    Ferrum College             Ferrum VA            51
# 34          Norfolk State University            Norfolk VA            55
# 35         Virginia State University         Petersburg VA            57
# 36                Averett University           Danville VA            62
# 37                   ECPI University     Virginia Beach VA           110
# 38              Bluefield University          Bluefield VA           112
# 39                Liberty University          Lynchburg VA       392-434
# 40         Virginia Union University           Richmond VA       187-204
#
#                           Category  Tuition (Out-of-State)  \
# 0            National Universities                   60907
# 1            National Universities                   37158
# 2            National Universities                   50752
# 3            National Universities                   38688
# 4            National Universities                   39194
# 5            National Universities                   31264
# 6            National Universities                   30842
# 7            National Universities                   40120
# 8            National Universities                   33780
# 9            National Universities                   25186
# 10           National Universities                   36028
# 11           National Universities                   36750
# 12           National Universities                   34152
# 13           National Universities                   21650
# 14  National Liberal Arts Colleges                   68045
# 15  National Liberal Arts Colleges                   65230
# 16  National Liberal Arts Colleges                   28860
# 17  National Liberal Arts Colleges                   54550
# 18  National Liberal Arts Colleges                   49466
# 19  National Liberal Arts Colleges                   36774
# 20  National Liberal Arts Colleges                   27560
# 21  National Liberal Arts Colleges                   43630
# 22  National Liberal Arts Colleges                   28425
# 23  National Liberal Arts Colleges                   29010
# 24  National Liberal Arts Colleges                   16090
# 25  National Liberal Arts Colleges                   26160
# 26  National Liberal Arts Colleges                   28009
# 27  National Liberal Arts Colleges                   37500
# 28  National Liberal Arts Colleges                   21860
# 29     Regional Universities South                   30778
# 30     Regional Universities South                   28076
# 31     Regional Universities South                   39000
# 32     Regional Universities South                   43070
# 33         Regional Colleges South                   27400
# 34     Regional Universities South                   21412
# 35     Regional Universities South                   21874
# 36     Regional Universities South                   38550
# 37     Regional Universities South                   17479
# 38     Regional Universities South                   24950
# 39           National Universities                   24600
# 40  National Liberal Arts Colleges                   17830
#
#     Tuition (In-State)  Undergraduate Enrollment  VA Rank
# 0                23118                     17618        1
# 1                15948                     30504        2
# 2                26019                      6963        3
# 3                14220                     27666        4
# 4                16720                     21205        5
# 5                13918                     21008        6
# 6                30842                      3255        7
# 7                40120                      2216        8
# 8                12750                     17736        9
# 9                12548                      5704       10
# 10               36028                      2590       11
# 11               36750                      1792       12
# 12               34152                      1202       13
# 13               21650                      4577       14
# 14               68045                      1898       15
# 15               65230                      3054       16
# 16               60452                      1560       17
# 17               54550                       876       18
# 18               49466                      1500       19
# 19               36774                      1809       20
# 20               14640                      3611       21
# 21               43630                       691       22
# 22               28425                       408       23
# 23               29010                       478       24
# 24               16090                      1391       25
# 25               26160                       464       26
# 26               17211                      1906       27
# 27               37500                      1626       28
# 28               21860                      1053       29
# 29               16828                      4407       30
# 30               15744                      3222       31
# 31               39000                      1106       32
# 32               43070                       892       33
# 33               27400                       835       34
# 34                9910                      5337       35
# 35               10043                      4829       36
# 36               38550                      1192       37
# 37               17479                     11399       38
# 38               24950                       705       39
# 39               24600                     52823       40
# 40               17830                      1170       41

# %% [markdown]
# ### Top 10 Universities in Virginia According to U.S. News Rankings
#
# This chart highlights the top 10 universities in Virginia based on the U.S. News & World Report rankings. The rankings provide insights into the academic reputation, tuition costs, and undergraduate enrollment of each institution.
#  - Esther Kim

# %%
df.head(11)
# Out:
#                                 Name            Location National Rank  \
# 0             University of Virginia  Charlottesville VA            24
# 1                      Virginia Tech       Blacksburg VA            51
# 2                     William & Mary     Williamsburg VA            54
# 3            George Mason University          Fairfax VA           109
# 4   Virginia Commonwealth University         Richmond VA           136
# 5           James Madison University     Harrisonburg VA           148
# 6                 Hampton University          Hampton VA           273
# 7               Marymount University        Arlington VA           288
# 8            Old Dominion University          Norfolk VA           296
# 9                 Radford University          Radford VA           315
# 10             Shenandoah University       Winchester VA           315
#
#                  Category  Tuition (Out-of-State)  Tuition (In-State)  \
# 0   National Universities                   60907               23118
# 1   National Universities                   37158               15948
# 2   National Universities                   50752               26019
# 3   National Universities                   38688               14220
# 4   National Universities                   39194               16720
# 5   National Universities                   31264               13918
# 6   National Universities                   30842               30842
# 7   National Universities                   40120               40120
# 8   National Universities                   33780               12750
# 9   National Universities                   25186               12548
# 10  National Universities                   36028               36028
#
#     Undergraduate Enrollment  VA Rank
# 0                      17618        1
# 1                      30504        2
# 2                       6963        3
# 3                      27666        4
# 4                      21205        5
# 5                      21008        6
# 6                       3255        7
# 7                       2216        8
# 8                      17736        9
# 9                       5704       10
# 10                      2590       11

# %% [markdown]
# ### Top 10 Virginia Universities by U.S. News Ranking: In-State vs. Out-of-State Tuition Comparison
#
# This chart presents the top 10 universities in Virginia as ranked by U.S. News, showing a comparison of in-state and out-of-state tuition costs. Each university's tuition fees are shown side-by-side illustrating the difference in cost for resident versus non-resident students.
#  - Esther Kim

# %%
import matplotlib.pyplot as plt


# convert tuition col to numeric values, and handling non numeric with coerce 
df['Tuition (Out-of-State)'] = pd.to_numeric(df['Tuition (Out-of-State)'], errors='coerce')
df['Tuition (In-State)'] = pd.to_numeric(df['Tuition (In-State)'], errors='coerce')

 
top_10_universities = df.head(10)  

# plot
fig, ax = plt.subplots(figsize=(12, 8))
width = 0.4  # bar width 
indices = np.arange(len(top_10_universities))  

# plotting both in state and out of state tuition side by side
ax.bar(indices - width/2, top_10_universities['Tuition (In-State)'], width, label='In-State Tuition', color='cornflowerblue')
ax.bar(indices + width/2, top_10_universities['Tuition (Out-of-State)'], width, label='Out-of-State Tuition', color='lightcoral')

# x axis and y axis
ax.set_xlabel('University Name')
ax.set_ylabel('Tuition Cost (USD)')
ax.set_title('Top 10 Universities by U.S. News with In-State and Out-of-State Tuition')
ax.set_xticks(indices)
ax.set_xticklabels(top_10_universities['Name'], rotation=45, ha="right")
ax.legend()

plt.tight_layout()   
plt.show()

# %% [markdown]
# When tuition for in-state and out-of-state is the same, that indicates its a private university, as is the case for Hampton University and Marymount University. UVA and William & Mary have the two highest in-state tuitions, where the remaining public universities are 9,000 dollars less or more than these two per school year in VA. However, UVA has the highest out-of-state tuiton, outpricing even the two private universities, at over 60,000 dollars a year.
# - Esther Kim, produced visualization above
# - Kaitlyn Green, wrote this cell

# %% [markdown]
# - Hieu Ngo, work starts here

# %% [markdown]
# ### Is there a correlation between university rankings and future median salaries for students?
# The work belows pulls data from institutions across the country, refines it to only schools in VA, and then merges this data with VA schools ranked by US News. The data is then displayed in linear regression graphs showing the correlation between national rankings of VA

# %%
### Imprort data file
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
data = pd.read_csv('Most-Recent-Cohorts-Institution.csv')
data.head()
# Out:
#    UNITID      OPEID   OPEID6                               INSTNM  \
# 0  100654   100200.0   1002.0             Alabama A & M University
# 1  100663   105200.0   1052.0  University of Alabama at Birmingham
# 2  100690  2503400.0  25034.0                   Amridge University
# 3  100706   105500.0   1055.0  University of Alabama in Huntsville
# 4  100724   100500.0   1005.0             Alabama State University
#
#          CITY STABBR         ZIP  \
# 0      Normal     AL       35762
# 1  Birmingham     AL  35294-0110
# 2  Montgomery     AL  36117-3553
# 3  Huntsville     AL       35899
# 4  Montgomery     AL  36104-0271
#
#                                         ACCREDAGENCY  \
# 0  Southern Association of Colleges and Schools C...
# 1  Southern Association of Colleges and Schools C...
# 2  Southern Association of Colleges and Schools C...
# 3  Southern Association of Colleges and Schools C...
# 4  Southern Association of Colleges and Schools C...
#
#                               INSTURL  \
# 0                       www.aamu.edu/
# 1                https://www.uab.edu/
# 2  https://www.amridgeuniversity.edu/
# 3                        www.uah.edu/
# 4                      www.alasu.edu/
#
#                                               NPCURL  ...  \
# 0  www.aamu.edu/admissions-aid/tuition-fees/net-p...  ...
# 1  https://tcc.ruffalonl.com/University of Alabam...  ...
# 2           https://www2.amridgeuniversity.edu:9091/  ...
# 3                                    finaid.uah.edu/  ...
# 4  www.alasu.edu/cost-aid/tuition-costs/net-price...  ...
#
#    COUNT_WNE_MALE0_P11  COUNT_WNE_MALE1_P11  GT_THRESHOLD_P11  \
# 0                800.0                777.0            0.6250
# 1               1811.0               1157.0            0.7588
# 2                 75.0                 67.0            0.5986
# 3                810.0                802.0            0.7810
# 4               1224.0               1049.0            0.5378
#
#    MD_EARN_WNE_INC1_P11  MD_EARN_WNE_INC2_P11  MD_EARN_WNE_INC3_P11  \
# 0               36650.0               41070.0               47016.0
# 1               47182.0               51896.0               54368.0
# 2               35752.0               41007.0                   NaN
# 3               51208.0               62219.0               62577.0
# 4               32844.0               36932.0               37966.0
#
#    MD_EARN_WNE_INDEP0_P11  MD_EARN_WNE_INDEP1_P11  MD_EARN_WNE_MALE0_P11  \
# 0                 38892.0                 41738.0                38167.0
# 1                 50488.0                 51505.0                46559.0
# 2                     NaN                 38467.0                32654.0
# 3                 55920.0                 60221.0                47787.0
# 4                 34294.0                 31797.0                32303.0
#
#    MD_EARN_WNE_MALE1_P11
# 0                40250.0
# 1                59181.0
# 2                49435.0
# 3                67454.0
# 4                36964.0
#
# [5 rows x 3305 columns]

# %%
df = pd.DataFrame(data)
VA_df = df[df['STABBR']=='VA']

# %%
### Creating data frame for Virginia Universities, sorting form highest to lowest median earning
### The dataframe includes Mediean_Earn_6: reflecting early career success 6 years after enrollment
### Median_Earn_8, Median_Earn_10: providing insights into more established earnings potential and career growth after 8 years and 10 years
new_df = pd.DataFrame({
    'Institution':VA_df['INSTNM'], 'City': VA_df['CITY'], 'State': VA_df['STABBR'], 'Median_Earn_6': VA_df['MD_EARN_WNE_P6'],
    'Median_Earn_8': VA_df['MD_EARN_WNE_P8'], 'Median_Earn_10': VA_df['MD_EARN_WNE_P10']
})
new_df.dropna()
sorted_df = new_df.sort_values(by='Median_Earn_6', ascending=False)
sorted_df.dropna()
# Out:
#                                             Institution             City  \
# 4986                    Chamberlain University-Virginia           Vienna
# 3343                 Sentara College of Health Sciences       Chesapeake
# 3387                      Washington and Lee University        Lexington
# 3359            Bon Secours Memorial College of Nursing         Richmond
# 3380                 University of Virginia-Main Campus  Charlottesville
# ...                                                 ...              ...
# 5129                Empire Beauty School-Virginia Beach   Virginia Beach
# 5955  Aveda Arts & Sciences Institute Lafayette-Arli...        Arlington
# 3353         Sylvain Melloul International Hair Academy        Lynchburg
# 3382                         Asher Institute of Hampton          Hampton
# 3303                   Paul Mitchell the School-Roanoke          Roanoke
#
#      State  Median_Earn_6  Median_Earn_8  Median_Earn_10
# 4986    VA        84533.0        88361.0         92405.0
# 3343    VA        78992.0        78797.0         77821.0
# 3387    VA        76516.0        89772.0         94810.0
# 3359    VA        75150.0        72735.0         77014.0
# 3380    VA        72359.0        80156.0         86863.0
# ...    ...            ...            ...             ...
# 5129    VA        20172.0        22421.0         24407.0
# 5955    VA        19975.0        21877.0         23904.0
# 3353    VA        17502.0        19574.0         17106.0
# 3382    VA        17178.0        18866.0         18710.0
# 3303    VA        13518.0        14995.0         19217.0
#
# [134 rows x 6 columns]

# %%
df = pd.read_csv('US_news_ranking_UPDATED.csv') 
df.fillna('Not Available', inplace=True)
df.head(11)
# Out:
#                                 Name            Location National Rank  \
# 0             University of Virginia  Charlottesville VA            24
# 1                      Virginia Tech       Blacksburg VA            51
# 2                     William & Mary     Williamsburg VA            54
# 3            George Mason University          Fairfax VA           109
# 4   Virginia Commonwealth University         Richmond VA           136
# 5           James Madison University     Harrisonburg VA           148
# 6                 Hampton University          Hampton VA           273
# 7               Marymount University        Arlington VA           288
# 8            Old Dominion University          Norfolk VA           296
# 9                 Radford University          Radford VA           315
# 10             Shenandoah University       Winchester VA           315
#
#                  Category  Tuition (Out-of-State)  Tuition (In-State)  \
# 0   National Universities                   60907               23118
# 1   National Universities                   37158               15948
# 2   National Universities                   50752               26019
# 3   National Universities                   38688               14220
# 4   National Universities                   39194               16720
# 5   National Universities                   31264               13918
# 6   National Universities                   30842               30842
# 7   National Universities                   40120               40120
# 8   National Universities                   33780               12750
# 9   National Universities                   25186               12548
# 10  National Universities                   36028               36028
#
#     Undergraduate Enrollment  VA Rank
# 0                      17618        1
# 1                      30504        2
# 2                       6963        3
# 3                      27666        4
# 4                      21205        5
# 5                      21008        6
# 6                       3255        7
# 7                       2216        8
# 8                      17736        9
# 9                       5704       10
# 10                      2590       11

# %%
### Merge university ranking dataframe and income dataframe to find the relation between them
merge_df = pd.merge(sorted_df,df,
                         left_on=['Institution'],
                         right_on=['Name'],
                         how='inner'
                        )
merge_df.head(38)
df['MaxRank'] = merge_df['National Rank'].apply(lambda x: max(map(int, x.split('-'))))
data = {
    'Name': merge_df["Name"],
    'Location': merge_df["Location"],
   'National Rank': df['MaxRank'],  
    'Median_Earn_6': merge_df["Median_Earn_6"],
    'Median_Earn_8': merge_df["Median_Earn_8"],
    'Median_Earn_10': merge_df["Median_Earn_10"]
    
}
rank_earn_df = pd.DataFrame(data)
clean_df = rank_earn_df.dropna()
clean_df
# Out:
#                                 Name              Location  National Rank  \
# 0      Washington and Lee University          Lexington VA           19.0
# 1             University of Richmond  Univ. of Richmond VA           22.0
# 2        Virginia Military Institute          Lexington VA           59.0
# 3                     William & Mary       Williamsburg VA           54.0
# 4            George Mason University            Fairfax VA          109.0
# 5               Marymount University          Arlington VA          288.0
# 6           James Madison University       Harrisonburg VA          148.0
# 7             Hampden-Sydney College     Hampden-Sydney VA          103.0
# 8     Christopher Newport University       Newport News VA            6.0
# 9      University of Mary Washington     Fredericksburg VA          132.0
# 10             Shenandoah University         Winchester VA          315.0
# 11      Eastern Mennonite University       Harrisonburg VA           48.0
# 12            Randolph-Macon College            Ashland VA          103.0
# 13  Virginia Commonwealth University           Richmond VA          136.0
# 14           Old Dominion University            Norfolk VA          296.0
# 15                Averett University           Danville VA           62.0
# 16               Longwood University          Farmville VA           15.0
# 17               Bridgewater College        Bridgewater VA          165.0
# 18                   Roanoke College              Salem VA          122.0
# 19                Radford University            Radford VA          315.0
# 20           University of Lynchburg          Lynchburg VA          329.0
# 21                Hampton University            Hampton VA          273.0
# 22                 Regent University     Virginia Beach VA          377.0
# 23              Bluefield University          Bluefield VA          112.0
# 24                   ECPI University     Virginia Beach VA          110.0
# 25                Liberty University          Lynchburg VA          434.0
# 26      Virginia Wesleyan University     Virginia Beach VA          175.0
# 27                  Randolph College          Lynchburg VA          162.0
# 28           Mary Baldwin University           Staunton VA          377.0
# 29      Southern Virginia University        Buena Vista VA          182.0
# 30                    Ferrum College             Ferrum VA           51.0
# 31               Sweet Briar College        Sweet Briar VA          173.0
# 32         Virginia State University         Petersburg VA           57.0
# 33          Norfolk State University            Norfolk VA           55.0
# 34                Hollins University            Roanoke VA          136.0
# 35         Virginia Union University           Richmond VA          204.0
#
#     Median_Earn_6  Median_Earn_8  Median_Earn_10
# 0         76516.0        89772.0         94810.0
# 1         67927.0        73948.0         76178.0
# 2         63545.0        78129.0         77369.0
# 3         62959.0        67721.0         73490.0
# 4         60536.0        68053.0         76343.0
# 5         57801.0        63019.0         67516.0
# 6         57438.0        64070.0         69954.0
# 7         55846.0        63236.0         67640.0
# 8         51931.0        57119.0         60509.0
# 9         49411.0        54986.0         60613.0
# 10        48167.0        52579.0         58433.0
# 11        48158.0        53356.0         54869.0
# 12        48067.0        54896.0         58448.0
# 13        47161.0        54212.0         58128.0
# 14        46732.0        51738.0         54914.0
# 15        46273.0        49603.0         51516.0
# 16        46058.0        48859.0         52347.0
# 17        45620.0        50239.0         53453.0
# 18        45330.0        52365.0         58047.0
# 19        44830.0        50773.0         53739.0
# 20        44261.0        49996.0         56380.0
# 21        42721.0        53813.0         59159.0
# 22        42066.0        43460.0         44498.0
# 23        41923.0        44360.0         48896.0
# 24        41278.0        43157.0         42837.0
# 25        39707.0        40638.0         44813.0
# 26        39200.0        47428.0         50074.0
# 27        39122.0        43738.0         53409.0
# 28        39075.0        42645.0         44427.0
# 29        36988.0        39289.0         50002.0
# 30        36418.0        41107.0         44296.0
# 31        35533.0        46254.0         51943.0
# 32        33630.0        39572.0         45543.0
# 33        33412.0        40645.0         44666.0
# 34        29863.0        37135.0         40075.0
# 35        27977.0        35235.0         38275.0

# %%
###Performing multiple linear regression between university ranking and median earning to understand the relation ship between them
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

X = clean_df[['National Rank']]
Y = clean_df[['Median_Earn_6', 'Median_Earn_8', 'Median_Earn_10']]

# Initialize and fit models
model6 = LinearRegression().fit(X, Y['Median_Earn_6'])
model8 = LinearRegression().fit(X, Y['Median_Earn_8'])
model10 = LinearRegression().fit(X, Y['Median_Earn_10'])
# Predict values and compute residuals
Y_pred6 = model6.predict(X)
residuals6 = Y['Median_Earn_6'] - Y_pred6

Y_pred8 = model8.predict(X)
residuals8 = Y['Median_Earn_8'] - Y_pred8

Y_pred10 = model10.predict(X)
residuals10 = Y['Median_Earn_10'] - Y_pred10
# Predict values
X_pred = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)
Y_pred6 = model6.predict(X_pred)
Y_pred8 = model8.predict(X_pred)
Y_pred10 = model10.predict(X_pred)

# Create scatter plots
plt.figure(figsize=(14, 10))

plt.subplot(3, 1, 1)
plt.scatter(X, Y['Median_Earn_6'], color='blue', label='Actual Earnings 6 Years')
plt.plot(X_pred, Y_pred6, color='red', label='Predicted Earnings 6 Years')
plt.title('University Ranking vs Earnings After 6 Years')
plt.xlabel('University Ranking')
plt.ylabel('Earnings After 6 Years')
plt.legend()

plt.subplot(3, 1, 2)
plt.scatter(X, Y['Median_Earn_8'], color='black', label='Actual Earnings 8 Years')
plt.plot(X_pred, Y_pred8, color='red', label='Predicted Earnings 8 Years')
plt.title('University Ranking vs Earnings After 8 Years')
plt.xlabel('University Ranking')
plt.ylabel('Earnings After 8 Years')
plt.legend()

plt.subplot(3, 1, 3)
plt.scatter(X, Y['Median_Earn_10'], color='purple', label='Actual Earnings 10 Years')
plt.plot(X_pred, Y_pred10, color='red', label='Predicted Earnings 10 Years')
plt.title('University Ranking vs Earnings After 10 Years')
plt.xlabel('University Ranking')
plt.ylabel('Earnings After 10 Years')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# - Hieu Ngo, work ends here

# %% [markdown]
# According to the linear regression plots when comparing national university rankings to to median earnings, after 6, 8, and 10 years, there is a negative correlation. So the lower or rather technically higher 'ranking' a university has, the lower the future median earnings of its students. A school that is rank 1 would have students with higher future median earnings than one at a rank 300 would.
# - Kaitlyn Green

# %% [markdown]
# - Jackson Rowley work start

# %% [markdown]
# ### Is there a correlation between tuition and university ranking?
#
# Does the ranking of a college effect its tuition, and how does that change with if that University is public or private? The data used comes from US news rankings and This work show the relationship between National rank and tuition, as well as how that changes based on if that university is public or private. (Using VA schools)

# %%
uni_rank = pd.read_csv('US_news_ranking_UPDATED.csv')

# %%
#creates column based on public vs private school
uni_rank['Class'] = ['Private' if uni_rank['Tuition (In-State)'][i] == uni_rank['Tuition (Out-of-State)'][i] else 'Public' for i in range(0, len(uni_rank))]

#computes tuition for each university
uni_rank['Avg_Tuition'] = (uni_rank['Tuition (In-State)'] + uni_rank['Tuition (Out-of-State)'])/2
uni_rank['National'] = uni_rank['National Rank']

#rank given in range -> mean of that range
uni_rank['National'][39] = (434+392)/2
uni_rank['National'][40] = (187+204)/2
#Makes national a float
uni_rank.National = uni_rank.National.map(lambda t: float(t))

# %%
#sorts values based on national ranking 
uni_rank = uni_rank.sort_values('National')

# %%
# colors for plot
colors = ['red' if uni_rank['Tuition (In-State)'][i] == uni_rank['Tuition (Out-of-State)'][i] else 'blue' for i in range(0, len(uni_rank))]

# %%
#Linear regression between Average tuition cost and rank for public schools
from sklearn.linear_model import LinearRegression

#dataframe for only public universities
pub_df = uni_rank[uni_rank.Class == 'Public']

Pub_X = pub_df[['National']]
Pub_Y = pub_df.Avg_Tuition

#fit model
pub_model = LinearRegression().fit(Pub_X, Pub_Y)

#creates column in dataframe
pub_df['Pred_pub'] = pub_model.predict(Pub_X)

# %%
#Linear regression between Average tuition cost and rank for public schools

#creates dataframe of private universities
priv_df = uni_rank[uni_rank.Class == 'Private']


Priv_X = priv_df[['National']]
Priv_Y = priv_df.Avg_Tuition

#fit model
priv_model = LinearRegression().fit(Priv_X, Priv_Y)

#create column in dataframe
priv_df['Pred_priv'] = priv_model.predict(Priv_X)

# %%
#Public vs Private school scatter Plot
axes = uni_rank[uni_rank.Class == 'Private'].plot.scatter(x = 'National', y = 'Avg_Tuition', color = 'red', label = 'Private School')
uni_rank[uni_rank.Class == 'Public'].plot.scatter(x = 'National', y = 'Avg_Tuition', color = 'blue', ax = axes, label = 'Public School',
                                                  rot = 90, title = 'Tuition vs National Ranking for Public and Private Schools',
                                                 ylabel = 'Average Tuition')
# Out:
# <Axes: title={'center': 'Tuition vs National Ranking for Public and Private Schools'}, xlabel='National', ylabel='Average Tuition'>

# %%
#Regression plots
ax3 = pub_df.plot(x = 'National', y = 'Pred_pub', color = 'blue', label = 'Public Regression')
priv_df.plot(x = 'National', y = 'Pred_priv', color = 'red', ax = ax3, label = 'Private Regression',
             ylabel = 'Average Tuition', title = "Linear Regression Public vs Private")
# Out:
# <Axes: title={'center': 'Linear Regression Public vs Private'}, xlabel='National', ylabel='Average Tuition'>

# %% [markdown]
# From this analysis we are able to conclude that based on the average tuition of public and private universities in virginia that public universities are on average going to cost significantly less to recieve a similar national ranking to that if a private university. As well as, this shows that as tuition cost rises in both public and private universities the ranking of that university improves.

# %% [markdown]
# - End Jackson work

# %% [markdown]
# - Ben Clements work start

# %% [markdown]
# ### Is there a correlation between university rankings and graduate employment rates in Virginia?

# %% [markdown]
# Previously cleaned data is used to determine the predicted immediate rate of employment from schools in Virginia based on ranking. The soonest data we have available from graduating or leaving school is 1 and 4 years, so we have two graphs representing both. The predicted rate is represented by a linear regression.

# %%
# Create data frames for 1 and 4 years that most importantly include the employment rate derived from the VA_df's
# working after leaving school and not working after leaving school columns

employment_1yr = pd.DataFrame({
    'Institution': VA_df['INSTNM'],
    'Working': VA_df['COUNT_WNE_1YR'],
    'Not_Working': VA_df['COUNT_NWNE_1YR']
})

employment_1yr['Total_Graduates'] = (employment_1yr['Working'] + employment_1yr['Not_Working'])
employment_1yr['Employment_Rate'] = (employment_1yr['Working'] / employment_1yr['Total_Graduates']) * 100

employment_4yr = pd.DataFrame({
    'Institution': VA_df['INSTNM'],
    'Working': VA_df['COUNT_WNE_4YR'],
    'Not_Working': VA_df['COUNT_NWNE_4YR']
})

employment_4yr['Total_Graduates'] = (employment_4yr['Working'] + employment_4yr['Not_Working'])
employment_4yr['Employment_Rate'] = (employment_4yr['Working'] / employment_4yr['Total_Graduates']) * 100

# %%
# Merge the cleaned dataframe of rankings with the created employment rate dataframes

rankings_4yr = pd.merge(clean_df, employment_4yr,
                               left_on='Name',
                               right_on='Institution',
                               how='inner'
                              )

rankings_1yr = pd.merge(clean_df, employment_1yr,
                                   left_on='Name',
                                   right_on='Institution',
                                   how='inner'
                                  )

# %%
# Create scatter plots with a linear regression to determine if there is any correlation

X_4yr = rankings_4yr[['National Rank']]
Y_4yr = rankings_4yr[['Employment_Rate']]

model_4yr = LinearRegression().fit(X_4yr, Y_4yr)

Y_pred_4yr = model_4yr.predict(X_4yr)
X_pred_4yr = np.linspace(X_4yr.min(), X_4yr.max(), 300).reshape(-1, 1)
Y_pred_4yr = model_4yr.predict(X_pred_4yr)

plt.figure(figsize=(14, 10))
plt.subplot(2, 1, 1)
plt.scatter(X_4yr, Y_4yr, color='blue', label='Actual Employment Rate after 4 Years')
plt.plot(X_pred_4yr, Y_pred_4yr, color='red', label='Predicted Employment Rate after 4 Years')
plt.title('University Ranking vs Graduate Employment Rates in Virginia after 4 Years')
plt.xlabel('University Ranking')
plt.ylabel('Employment Rate %')
plt.legend()

X_1yr = rankings_1yr[['National Rank']]
Y_1yr = rankings_1yr[['Employment_Rate']]

model_1yr = LinearRegression().fit(X_1yr, Y_1yr)

Y_pred_1yr = model_1yr.predict(X_1yr)
X_pred_1yr = np.linspace(X_1yr.min(), X_1yr.max(), 300).reshape(-1, 1)
Y_pred_1yr = model_1yr.predict(X_pred_1yr)

plt.figure(figsize=(14, 10))
plt.subplot(2, 1, 1)
plt.scatter(X_1yr, Y_1yr, color='blue', label='Actual Employment Rate after 1 Year')
plt.plot(X_pred_1yr, Y_pred_1yr, color='red', label='Predicted Employment Rate after 1 Year')
plt.title('University Ranking vs Graduate Employment Rates in Virginia after 1 Year')
plt.xlabel('University Ranking')
plt.ylabel('Employment Rate %')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Although there is a negative correlation for both graphs, it is very mundane. The slope is very close to being flat percentage wise (~1% total change across entire trend). We can conclude that there is a meager correlation for a higher rate of employment for students leaving a higher ranked university vs a lower ranked university, but it is so small of a difference that it does not really matter. We can see that university ranking influences salary significantly more than general employment.

# %% [markdown]
# ### Procedural Section
# We added a new research question: "Is there a correlation between tuition and university ranking?"

# %% [markdown]
# - End Ben Clements work
